# %%
import pandas as pd
import numpy as np
import statistics
from scipy import stats
pd.read_csv("C:\\Users\\bharvath\\Downloads\\la.csv")
dat=pd.read_csv("C:\\Users\\bharvath\\Downloads\\la.csv")
df=pd.DataFrame(dat)
df.info()
cols=[1,2,3,4,5,7,8,9,10,11,12,13]
df=df[df.columns[cols]]
df.head()
mv=df['Crime Code'].mean()
mv
del df['MO Codes']
df
df['Time Occurred']=df['Time Occurred'].fillna(df['Time Occurred'].mean())
df.info()
df['Victim Age']=df['Victim Age'].fillna(df['Victim Age'].mean())
df['Premise Code']=df['Premise Code'].fillna(df['Premise Code'].mean())
df.info()
df['Victim Sex']=df['Victim Sex'].fillna("Any Victim")
df.info()
df['Victim Descent']=df['Victim Descent'].fillna("Any Descent")
df.info()
df
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
   
ps = PorterStemmer()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 23 columns):
# Date Reported                        499 non-null object
# Date Occurred                        499 non-null object
# Time Occurred                        499 non-null int64
# Area ID                              499 non-null int64
# Area Name                            499 non-null object
# Reporting District                   499 non-null int64
# Crime Code                           499 non-null int64
# Crime Code Description               499 non-null object
# MO Codes                             218 non-null object
# Victim Age                           467 non-null float64
# Victim Sex                           498 non-null object
# Victim Descent                       498 non-null object
# Premise Code                         499 non-null int64
# Premise Description                  499 non-null object
# Address                              499 non-null object
# ...

# %%
df.mean()
# Out:
# Time Occurred    1345.997691
# Area ID            10.415704
# Crime Code        997.000000
# Victim Age         38.791155
# Premise Code      101.249423
# dtype: float64

# %%
df.median()
# Out:
# Time Occurred    1430.0
# Area ID            11.0
# Crime Code        997.0
# Victim Age         38.0
# Premise Code      101.0
# dtype: float64

# %%
df.mode()
# Out:
#              Date Reported            Date Occurred  Time Occurred  Area ID  \
# 0  2019-06-12T00:00:00.000  2019-06-11T00:00:00.000            800        1
#
#   Area Name  Crime Code Crime Code Description  Victim Age Victim Sex  \
# 0   Central         997      TRAFFIC COLLISION        18.0          M
#
#   Victim Descent  Premise Code
# 0              H           101

# %%
gmean=stats.gmean(df.Area ID)
print('gmean is',gmean)
# Out:
#   File "<ipython-input-7-2e7b1402a4ff>", line 1
#     gmean=stats.gmean(df.Area ID)
#                                ^
# SyntaxError: invalid syntax

# %%
from scipy import stats

# %%
gmean=stats.gmean(df.Area ID)
print('gmean is',gmean)
# Out:
#   File "<ipython-input-9-2e7b1402a4ff>", line 1
#     gmean=stats.gmean(df.Area ID)
#                                ^
# SyntaxError: invalid syntax

# %%
gmean=stats.gmean(df['Area ID'])
print('gmean is',gmean)
# Out:
# gmean is 7.841158208456369

# %%
hmean=stats.hmean(df['Area ID'])
print('hmean is',hmean)
# Out:
# hmean is 4.823285125142514

# %%
df.describe()

# %%
plt.hist(df.Area ID)

# %%
plt.hist(df.Area ID)

# %%
plt.hist(df['Area ID'])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Area ID'])

# %%
freq = {}

# %%
for item in df.Victim Age: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1

# %%
for item in df['Victim Age']: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1

# %%
key=[x for x in freq.keys()]

# %%
key

# %%
value=[freq[x] for x in freq.keys()]
value

# %%
plt.pie(value,labels=key,autopct='%.1f%%',startangle=90)
plt.show()

# %%
plt.bar(key,value)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f665968553e7> in <module>
# ----> 1 plt.bar(key,value)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['1', '2', '3', '4', '5'])
df.plot.box(grid='True')

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['1', '2', '3', '4', '5'])
df.plot.box(grid='False')

# %%
df
# Out:
#                Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    2019-08-03T00:00:00.000           1035       16     Foothill
# 1    2019-08-03T00:00:00.000            330        2      Rampart
# 2    2019-08-03T00:00:00.000           1300        9     Van Nuys
# 3    2019-08-03T00:00:00.000           1410        9     Van Nuys
# 4    2019-08-03T00:00:00.000            945       10  West Valley
# 5    2019-08-03T00:00:00.000           1250       19      Mission
# 6    2019-08-03T00:00:00.000           1405        9     Van Nuys
# 7    2019-08-03T00:00:00.000            140       15  N Hollywood
# 8    2019-08-03T00:00:00.000           1240       19      Mission
# 9    2019-08-03T00:00:00.000           1210       20      Olympic
# 10   2019-08-03T00:00:00.000            715       16     Foothill
# 11   2019-08-03T00:00:00.000            300       19      Mission
# 12   2019-08-03T00:00:00.000           1605        7     Wilshire
# ...

# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import numpy as np
import statistics
from scipy import stats
import csv
with open("C:\\Users\\bharvath\\Downloads\\la.csv", 'r') as f:
    wines = list(csv.reader(f, delimiter=";"))

import numpy as np
wines = np.array(wines, dtype=np.float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f343157e931d> in <module>
#      10
#      11 import numpy as np
# ---> 12 wines = np.array(wines[columns['Victim Age']], dtype=np.float)
#      13
#
# NameError: name 'columns' is not defined

# %%
DF.INFO()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ba7cf4c71093> in <module>
# ----> 1 DF.INFO()
#
# NameError: name 'DF' is not defined
